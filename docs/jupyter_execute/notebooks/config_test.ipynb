# %%
from rapi import Client

cl = Client()
cl.get_stations()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-V] [-dc] [-tp TEST_PAR]
#                              [-te TEST_ENV] [-td TEST_DEF] [-ta TEST_ALT]
#                              [-tc TEST_CFG_PRIO] [-tl] [-db] [-di DINT]
#                              {tsub,station,show,show_ep_filter} ...
# ipykernel_launcher.py: error: argument subcommand: invalid choice: '/tmp/tmpa08xlwrg.json' (choose from 'tsub', 'station', 'show', 'show_ep_filter')
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File /usr/lib/python3.11/argparse.py:1902, in ArgumentParser.parse_known_args(self, args, namespace)
#    1901 try:
# -> 1902     namespace, args = self._parse_known_args(args, namespace)
#    1903 except ArgumentError as err:
#
# File /usr/lib/python3.11/argparse.py:2096, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2095 if start_index != next_option_string_index:
# ...
